# %%
import requests
from bs4 import BeautifulSoup
res = requests.get('https://www.dcard.tw/f/funny')
soup = BeautifulSoup(res.text)
for tit in soup.select('.PostEntry_container_245XM'):
    print(tit.select('.PostLikeCount_likeCount_2uhBH')[0].text, tit.select('.PostEntry_title_t1BVP')[0])
# Out:
# (u'3046', <strong class="PostEntry_title_t1BVP" data-reactid="409">\u90a3\u4e9b\u5e74\u6211\u5011\u7684\u6953\u4e4b\u8c37\u5f0f\u6200\u611b</strong>)
# (u'2544', <strong class="PostEntry_title_t1BVP" data-reactid="426">#\u66f4#\u5716 \u5973\u53cb\u98ef\u524d\u8207\u98ef\u5f8c</strong>)
# (u'1301', <strong class="PostEntry_title_t1BVP" data-reactid="443">Total\u8ddf\u4f60\u6536500</strong>)
# (u'1234', <strong class="PostEntry_title_t1BVP" data-reactid="460">\u55ac\u5976\uff06\u55ac\u5c4c</strong>)
# (u'782', <strong class="PostEntry_title_t1BVP" data-reactid="480">\u5e97\u54e1\uff1a\u6211\u7d2f\u4e86XD</strong>)
# (u'717', <strong class="PostEntry_title_t1BVP" data-reactid="497">\u60c5\u4fb6\u9593\u6700\u795e\u5947\u7684\u4e09\u500b\u5b57</strong>)
# (u'510', <strong class="PostEntry_title_t1BVP" data-reactid="514">\u4f60\u6709\u8ce3\u7cbe\u5b50\u55ce?(\u5fae\u897f\u65af)</strong>)
# ...

# %%
import requests
from bs4 import BeautifulSoup
res = requests.get('https://www.dcard.tw/f/funny')
soup = BeautifulSoup(res.text)
for tit in soup.select('div'):
    print(soup.select('.PostLikeCount_likeCount_2uhBH')[0].text, soup.select('.PostEntry_title_t1BVP')[0].text)
# Out:
# (u'2787', u'\u90a3\u4e9b\u5e74\u6211\u5011\u7684\u6953\u4e4b\u8c37\u5f0f\u6200\u611b')
# (u'2787', u'\u90a3\u4e9b\u5e74\u6211\u5011\u7684\u6953\u4e4b\u8c37\u5f0f\u6200\u611b')
# (u'2787', u'\u90a3\u4e9b\u5e74\u6211\u5011\u7684\u6953\u4e4b\u8c37\u5f0f\u6200\u611b')
# (u'2787', u'\u90a3\u4e9b\u5e74\u6211\u5011\u7684\u6953\u4e4b\u8c37\u5f0f\u6200\u611b')
# (u'2787', u'\u90a3\u4e9b\u5e74\u6211\u5011\u7684\u6953\u4e4b\u8c37\u5f0f\u6200\u611b')
# (u'2787', u'\u90a3\u4e9b\u5e74\u6211\u5011\u7684\u6953\u4e4b\u8c37\u5f0f\u6200\u611b')
# (u'2787', u'\u90a3\u4e9b\u5e74\u6211\u5011\u7684\u6953\u4e4b\u8c37\u5f0f\u6200\u611b')
# (u'2787', u'\u90a3\u4e9b\u5e74\u6211\u5011\u7684\u6953\u4e4b\u8c37\u5f0f\u6200\u611b')
# (u'2787', u'\u90a3\u4e9b\u5e74\u6211\u5011\u7684\u6953\u4e4b\u8c37\u5f0f\u6200\u611b')
# (u'2787', u'\u90a3\u4e9b\u5e74\u6211\u5011\u7684\u6953\u4e4b\u8c37\u5f0f\u6200\u611b')
# (u'2787', u'\u90a3\u4e9b\u5e74\u6211\u5011\u7684\u6953\u4e4b\u8c37\u5f0f\u6200\u611b')
# ...

# %%
import requests
from bs4 import BeautifulSoup
res = requests.get('https://www.dcard.tw/f/funny')
soup = BeautifulSoup(res.text)
for tit in soup.select('class'):
    print(tit.text)
